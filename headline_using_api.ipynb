# %%
import requests

api_key = '8718b875d26242d2a50311fedd85daf8'
url = f'https://newsapi.org/v2/everything?q=stock&language=en&apiKey={api_key}'
response = requests.get(url)
data = response.json()

for article in data['articles']:
    print(article['title'])  # Headline
# Out:
# 7 Best Eco-Friendly Cleaning Products (2025)
# Apple has its biggest stock drop in five years because of Trump’s tariffs
# Apple has its biggest stock drop in five years because of Trump’s tariffs
# Stocks Plunge After Trump Declares Web Rumor on Tariffs ‘Fake News’
# Star Wars, Harry Potter: Amazon Clears Stock Of Popular Lego Sets Up To 40% Off
# Autonomous AI Could Wreak Havoc on Stock Market, Bank of England Warns
# Amazon Is Clearing Out Its Stock of These Older MacBook Airs, Now Almost 40% Off
# Amazon Just Marked Down This Lightning-Fast Portable SanDisk Flash Drive to Clear Out Stock
# DOGE Aide Involved in Dismantling Consumer Bureau Owns Stock in Companies That Could Benefit From Cuts
# The 2025 MacBook Air Has Never Been So Cheap, Amazon Clears Out Stock at a Record Low Price
# Google Pixel Watch 2 Hits an All-Time Low as Amazon Clears Out Remaining Stock, Nearly 50% Off
# Jaguar Land Rover pauses US shipments over Trump tariffs
# ...
